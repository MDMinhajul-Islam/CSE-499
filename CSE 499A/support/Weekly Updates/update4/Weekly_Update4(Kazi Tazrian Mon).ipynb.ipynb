# %%
# !pip install torch torchvision numpy matplotlib

# %%
from torchvision import datasets, transforms
train_transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
])
dataset = datasets.CelebA(root='./data', split='train', download=True, transform=train_transform)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=0B7EVK8r0v71pZjFTYXZWM3FlRnM
# From (redirected): https://drive.usercontent.google.com/download?id=0B7EVK8r0v71pZjFTYXZWM3FlRnM&confirm=t&uuid=e24c4650-04ce-44fa-9cc5-9c021d035348
# To: /content/data/celeba/img_align_celeba.zip
# 100%|██████████| 1.44G/1.44G [00:20<00:00, 70.8MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=0B7EVK8r0v71pblRyaVFSWGxPY0U
# To: /content/data/celeba/list_attr_celeba.txt
# 100%|██████████| 26.7M/26.7M [00:00<00:00, 40.1MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1_ee_0u7vcNLOfNLegJRHmolfH5ICW-XS
# To: /content/data/celeba/identity_CelebA.txt
# 100%|██████████| 3.42M/3.42M [00:00<00:00, 35.4MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=0B7EVK8r0v71pbThiMVRxWXZ4dU0
# To: /content/data/celeba/list_bbox_celeba.txt
# 100%|██████████| 6.08M/6.08M [00:00<00:00, 195MB/s]
# Downloading...
# ...

# %%
class DeepImagePrior(nn.Module):
    def __init__(self):
        super(DeepImagePrior, self).__init__()
        # Define your model layers here

    def forward(self, x):
        # Apply the forward pass
        return x

# %%
class DeepImagePrior(nn.Module):
    def __init__(self):
        super(DeepImagePrior, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        # Define other layers here

    def forward(self, x):
        # Apply the forward pass
        x = self.conv1(x)
        x = self.conv2(x)
        return x

# %%
model = DeepImagePrior().to(device)
print(list(model.parameters()))  # Check if there are parameters
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
# Out:
# [Parameter containing:
# tensor([[[[-0.0868,  0.1351,  0.0681],
#           [-0.0643, -0.0495,  0.1902],
#           [ 0.0696,  0.1839,  0.1256]],
#
#          [[-0.0443, -0.0139,  0.1704],
#           [-0.0384, -0.0666, -0.1099],
#           [-0.1347,  0.0064, -0.0134]],
#
#          [[-0.0753,  0.0743, -0.0866],
#           [-0.1687,  0.0420, -0.0706],
#           [ 0.0368,  0.0288,  0.1379]]],
#
#
#         [[[-0.1518, -0.1365,  0.1408],
#           [ 0.0698,  0.0374,  0.1785],
#           [-0.1011, -0.1595,  0.1568]],
#
#          [[-0.1443, -0.1639,  0.1891],
#           [ 0.1456, -0.0591,  0.0920],
#           [ 0.0270, -0.1756,  0.0109]],
#
#          [[-0.0348,  0.0970,  0.0922],
#           [-0.1564, -0.1760,  0.0479],
#           [ 0.0363, -0.0188,  0.1517]]],
#
#
#         [[[-0.0393, -0.1597, -0.1563],
#           [ 0.0084, -0.0023, -0.0637],
#           [-0.1563, -0.1822, -0.1898]],
#
#          [[-0.0369, -0.1751,  0.0511],
#           [-0.0659,  0.1531, -0.1301],
# ...

# %%
model = DeepImagePrior().to(device)
print(list(model.parameters()))  # This should not be an empty list
# Out:
# [Parameter containing:
# tensor([[[[ 0.1900, -0.0168,  0.0187],
#           [-0.0670, -0.0809,  0.0126],
#           [-0.0421,  0.0046,  0.1345]],
#
#          [[ 0.0460, -0.1446,  0.0103],
#           [-0.1202, -0.0803, -0.0588],
#           [-0.1918,  0.1163, -0.0704]],
#
#          [[ 0.0217,  0.1645, -0.1126],
#           [-0.0919,  0.1889,  0.1695],
#           [ 0.0354, -0.1031, -0.0666]]],
#
#
#         [[[ 0.1808,  0.0783, -0.1252],
#           [ 0.1437,  0.0613,  0.1460],
#           [ 0.1048, -0.1698,  0.0868]],
#
#          [[-0.1133,  0.0481, -0.0475],
#           [-0.1500,  0.0548,  0.0924],
#           [-0.0350, -0.0151, -0.0656]],
#
#          [[-0.1596, -0.1880,  0.0803],
#           [ 0.0116, -0.0034, -0.1344],
#           [ 0.0197,  0.0856,  0.0662]]],
#
#
#         [[[-0.0354, -0.0069,  0.0508],
#           [ 0.0715,  0.1633,  0.1891],
#           [-0.0639, -0.1731,  0.0488]],
#
#          [[-0.0932,  0.1915, -0.1449],
#           [-0.1923, -0.0497, -0.1100],
# ...

# %%
num_epochs = 10 # Define the number of epochs
for epoch in range(num_epochs):
    for data in train_loader:
        inputs, targets = data
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()  # Clear gradients
        outputs = model(inputs)  # Forward pass
        loss = criterion(outputs, targets)  # Compute loss
        loss.backward()  # Backpropagate
        optimizer.step()  # Update weights

        if epoch % 10 == 0:  # Print loss every 10 epochs
            print(f'Epoch [{epoch}/{num_epochs}], Loss: {loss.item():.4f}')
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /tmp/ipython-input-321941534.py in <cell line: 0>()
#       5         inputs, targets = inputs.to(device), targets.to(device)
#       6         optimizer.zero_grad()  # Clear gradients
# ----> 7         outputs = model(inputs)  # Forward pass
#       8         loss = criterion(outputs, targets)  # Compute loss
#       9         loss.backward()  # Backpropagate
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# ...

# %%
# Define the number of epochs
num_epochs = 10  # You can adjust this number based on how long you want to train

for epoch in range(num_epochs):
    for data in train_loader:
        inputs, targets = data
        inputs, targets = inputs.to(device), targets.to(device)

        optimizer.zero_grad()  # Clear gradients
        outputs = model(inputs)  # Forward pass
        loss = criterion(outputs, targets)  # Compute loss

        loss.backward()  # Backpropagate
        optimizer.step()  # Update weights

    # Print loss every 10 epochs
    if epoch % 10 == 0:
        print(f'Epoch [{epoch}/{num_epochs}], Loss: {loss.item():.4f}')
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /tmp/ipython-input-2075188050.py in <cell line: 0>()
#       8
#       9         optimizer.zero_grad()  # Clear gradients
# ---> 10         outputs = model(inputs)  # Forward pass
#      11         loss = criterion(outputs, targets)  # Compute loss
#      12
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
# ...
